# %%
from utils import *

# %%
X_1, y_1 = load_hyperspectral_dataset("indian_pines")
X_2, y_2 = load_hyperspectral_dataset("salinas_valley")
X_3, y_3 = load_hyperspectral_dataset("pavia_center")
X_4, y_4 = load_hyperspectral_dataset("pavia_university")

# %%
X_5, y_5 = load_hyperspectral_dataset("indian_pines", classes_to_drop=[0, 1, 7, 9, 16])

# %%
print_class_distribution("indian_pines", y_1)
# Out:
# ...
# CLASS DISTRIBUTION: INDIAN_PINES
# ...
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 10776
# 1    | Alfalfa                        | 46
# 2    | Corn-notill                    | 1428
# 3    | Corn-mintill                   | 830
# 4    | Corn                           | 237
# 5    | Grass-pasture                  | 483
# 6    | Grass-trees                    | 730
# 7    | Grass-pasture-mowed            | 28
# 8    | Hay-windrowed                  | 478
# 9    | Oats                           | 20
# 10   | Soybean-notill                 | 972
# 11   | Soybean-mintill                | 2455
# 12   | Soybean-clean                  | 593
# 13   | Wheat                          | 205
# 14   | Woods                          | 1265
# 15   | Buildings-Grass-Trees-Drives   | 386
# 16   | Stone-Steel-Towers             | 93
# --------------------------------------------------
# ...

# %%
print_class_distribution("salinas_valley", y_2)
# Out:
# ...
# CLASS DISTRIBUTION: SALINAS_VALLEY
# ...
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 56975
# 1    | Brocoli_green_weeds_1          | 2009
# 2    | Brocoli_green_weeds_2          | 3726
# 3    | Fallow                         | 1976
# 4    | Fallow_rough_plow              | 1394
# 5    | Fallow_smooth                  | 2678
# 6    | Stubble                        | 3959
# 7    | Celery                         | 3579
# 8    | Grapes_untrained               | 11271
# 9    | Soil_vinyard_develop           | 6203
# 10   | Corn_senesced_green_weeds      | 3278
# 11   | Lettuce_romaine_4wk            | 1068
# 12   | Lettuce_romaine_5wk            | 1927
# 13   | Lettuce_romaine_6wk            | 916
# 14   | Lettuce_romaine_7wk            | 1070
# 15   | Vinyard_untrained              | 7268
# 16   | Vinyard_vertical_trellis       | 1807
# --------------------------------------------------
# ...

# %%
print_class_distribution("pavia_center", y_3)
# Out:
# ...
# CLASS DISTRIBUTION: PAVIA_CENTER
# ...
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 635488
# 1    | Water                          | 65971
# 2    | Trees                          | 7598
# 3    | Asphalt                        | 3090
# 4    | Self-Blocking Bricks           | 2685
# 5    | Bitumen                        | 6584
# 6    | Tiles                          | 9248
# 7    | Shadows                        | 7287
# 8    | Meadows                        | 42826
# 9    | Bare Soil                      | 2863
# --------------------------------------------------
# TOTAL                                 783640
# ...

# %%
print_class_distribution("pavia_university", y_4)
# Out:
# ...
# CLASS DISTRIBUTION: PAVIA_UNIVERSITY
# ...
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 164624
# 1    | Asphalt                        | 6631
# 2    | Meadows                        | 18649
# 3    | Gravel                         | 2099
# 4    | Trees                          | 3064
# 5    | Painted metal sheets           | 1345
# 6    | Bare Soil                      | 5029
# 7    | Bitumen                        | 1330
# 8    | Self-Blocking Bricks           | 3682
# 9    | Shadows                        | 947
# --------------------------------------------------
# TOTAL                                 207400
# ...

# %%
X_norm, _ = normalize_features(X_1)
print(X_norm[4])
print(len(X_norm[4]))
# Out:
# Dataset normalized using Min-Max scaling (Feature-wise).
# Global Min: 0.00, Global Max: 1.00
# [0.09412955 0.43130148 0.37831858 0.45242117 0.31572593 0.27038736
#  0.28294393 0.28876378 0.299389   0.39758567 0.40699433 0.42505635
#  0.4229572  0.42518657 0.43744085 0.44143126 0.4525107  0.44216042
#  0.42986612 0.41542027 0.43005731 0.42748895 0.41864911 0.43199482
#  0.44821695 0.44767565 0.45595628 0.46603971 0.47481108 0.48041285
#  0.47752809 0.4378849  0.44357566 0.44935658 0.46508075 0.47077847
#  0.48231061 0.45091712 0.38187329 0.41382766 0.4101115  0.40388769
#  0.40945513 0.40595994 0.40788543 0.4031477  0.41688654 0.41358861
#  0.41669559 0.41724783 0.40932278 0.41432269 0.42547186 0.43582224
#  0.44223394 0.45343928 0.22678623 0.50645161 0.5199765  0.56295467
#  0.53485162 0.52819074 0.52662009 0.52393443 0.5166704  0.5129683
#  0.50726907 0.49866667 0.49326448 0.48748591 0.48815606 0.49134199
#  0.49975345 0.4964539  0.27398951 0.51471825 0.5125     0.51515152
# ...

# %% [markdown]
# The dataset is succesfully normalized

# %%
# plot_spectral_signatures("indian_pines", classes_to_plot=[2,3,4,10,11,12])
# plot_spectral_signatures("indian_pines", classes_to_plot=[2,10,11])
# plot_spectral_signatures("indian_pines", classes_to_plot=[4,12])
# plot_spectral_signatures("indian_pines", classes_to_plot=[14,15])
# plot_spectral_signatures("indian_pines", classes_to_plot=[6,14,15])

# plot_spectral_signatures("salinas_valley", classes_to_plot=[8,15])
# plot_spectral_signatures("salinas_valley", classes_to_plot=[8,9,16])

# plot_spectral_signatures("pavia_center", classes_to_plot=[4,5,6,7,8])
# plot_spectral_signatures("pavia_center", classes_to_plot=[2,3])

plot_spectral_signatures("pavia_university", classes_to_plot=[2,6])
plot_spectral_signatures("pavia_university", classes_to_plot=[1,3,8])

# %%
# print(plot_color_composites("salinas_valley", composites=["RGB", "NIR-G-B"]))
# print(plot_color_composites("pavia_center", composites=["RGB", "NIR-G-B"]))
# print(plot_color_composites("pavia_university", composites=["RGB", "NIR-G-B"]))
print(plot_color_composites("indian_pines", classes_to_plot=[14], composites=["RGB", "NIR-G-B"]))
print(plot_color_composites("indian_pines", classes_to_plot=[15], composites=["RGB", "NIR-G-B"]))
# Out:
# None
# None
