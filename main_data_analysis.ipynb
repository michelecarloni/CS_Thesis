# %%
from utils import *

# %%
X_1, y_1 = load_hyperspectral_dataset("indian_pines")
X_2, y_2 = load_hyperspectral_dataset("salinas_valley")
X_3, y_3 = load_hyperspectral_dataset("pavia_center")
X_4, y_4 = load_hyperspectral_dataset("pavia_university")

# %%
X_5, y_5 = load_hyperspectral_dataset("indian_pines", classes_to_drop=[0, 1, 7, 9, 16])

# %%
print_class_distribution("indian_pines", y_1)
# Out:
# ==================================================
# CLASS DISTRIBUTION: INDIAN_PINES
# ==================================================
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 10776
# 1    | Alfalfa                        | 46
# 2    | Corn-notill                    | 1428
# 3    | Corn-mintill                   | 830
# 4    | Corn                           | 237
# 5    | Grass-pasture                  | 483
# 6    | Grass-trees                    | 730
# 7    | Grass-pasture-mowed            | 28
# 8    | Hay-windrowed                  | 478
# 9    | Oats                           | 20
# 10   | Soybean-notill                 | 972
# 11   | Soybean-mintill                | 2455
# 12   | Soybean-clean                  | 593
# 13   | Wheat                          | 205
# 14   | Woods                          | 1265
# 15   | Buildings-Grass-Trees-Drives   | 386
# 16   | Stone-Steel-Towers             | 93
# --------------------------------------------------
# TOTAL                                 21025
# ==================================================

# %%
print_class_distribution("indian_pines", y_5)
# Out:
# ==================================================
# CLASS DISTRIBUTION: INDIAN_PINES
# ==================================================
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 2    | Corn-notill                    | 1428
# 3    | Corn-mintill                   | 830
# 4    | Corn                           | 237
# 5    | Grass-pasture                  | 483
# 6    | Grass-trees                    | 730
# 8    | Hay-windrowed                  | 478
# 10   | Soybean-notill                 | 972
# 11   | Soybean-mintill                | 2455
# 12   | Soybean-clean                  | 593
# 13   | Wheat                          | 205
# 14   | Woods                          | 1265
# 15   | Buildings-Grass-Trees-Drives   | 386
# --------------------------------------------------
# TOTAL                                 10062
# ==================================================

# %%
print_class_distribution("salinas_valley", y_2)
# Out:
# ==================================================
# CLASS DISTRIBUTION: SALINAS_VALLEY
# ==================================================
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 56975
# 1    | Brocoli_green_weeds_1          | 2009
# 2    | Brocoli_green_weeds_2          | 3726
# 3    | Fallow                         | 1976
# 4    | Fallow_rough_plow              | 1394
# 5    | Fallow_smooth                  | 2678
# 6    | Stubble                        | 3959
# 7    | Celery                         | 3579
# 8    | Grapes_untrained               | 11271
# 9    | Soil_vinyard_develop           | 6203
# 10   | Corn_senesced_green_weeds      | 3278
# 11   | Lettuce_romaine_4wk            | 1068
# 12   | Lettuce_romaine_5wk            | 1927
# 13   | Lettuce_romaine_6wk            | 916
# 14   | Lettuce_romaine_7wk            | 1070
# 15   | Vinyard_untrained              | 7268
# 16   | Vinyard_vertical_trellis       | 1807
# --------------------------------------------------
# TOTAL                                 111104
# ==================================================

# %%
print_class_distribution("pavia_center", y_3)
# Out:
# ==================================================
# CLASS DISTRIBUTION: PAVIA_CENTER
# ==================================================
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 635488
# 1    | Water                          | 65971
# 2    | Trees                          | 7598
# 3    | Asphalt                        | 3090
# 4    | Self-Blocking Bricks           | 2685
# 5    | Bitumen                        | 6584
# 6    | Tiles                          | 9248
# 7    | Shadows                        | 7287
# 8    | Meadows                        | 42826
# 9    | Bare Soil                      | 2863
# --------------------------------------------------
# TOTAL                                 783640
# ==================================================

# %%
print_class_distribution("pavia_university", y_4)
# Out:
# ==================================================
# CLASS DISTRIBUTION: PAVIA_UNIVERSITY
# ==================================================
# ID   | Class Name                     | Samples
# --------------------------------------------------
# 0    | Background                     | 164624
# 1    | Asphalt                        | 6631
# 2    | Meadows                        | 18649
# 3    | Gravel                         | 2099
# 4    | Trees                          | 3064
# 5    | Painted metal sheets           | 1345
# 6    | Bare Soil                      | 5029
# 7    | Bitumen                        | 1330
# 8    | Self-Blocking Bricks           | 3682
# 9    | Shadows                        | 947
# --------------------------------------------------
# TOTAL                                 207400
# ==================================================

# %%
X_norm, _ = normalize_features(X_1)
print(X_norm[4])
print(len(X_norm[4]))
# Out:
# Dataset normalized using Min-Max scaling (Feature-wise).
# Global Min: 0.00, Global Max: 1.00
# [0.09412955 0.46200499 0.39982913 0.321513   0.30864198 0.26966902
#  0.27887105 0.27592267 0.28771016 0.28959496 0.41194149 0.42279914
#  0.42310789 0.4166342  0.43040435 0.43337196 0.44725905 0.44216042
#  0.42986612 0.41542027 0.43005731 0.42748895 0.4137931  0.42692224
#  0.44322344 0.43970715 0.45152049 0.46278385 0.47436975 0.47722445
#  0.47380074 0.45905707 0.44942812 0.46174557 0.50929095 0.55743982
#  0.51603935 0.45007654 0.37318894 0.41382766 0.39637387 0.40388769
#  0.40227088 0.39562624 0.40788543 0.4031477  0.41589579 0.41219429
#  0.41158964 0.41214825 0.40270366 0.40424785 0.41441927 0.41945218
#  0.42811502 0.43287812 0.19463694 0.47710185 0.48584015 0.54327485
#  0.50313306 0.49850924 0.49808429 0.49266247 0.48669202 0.48403006
#  0.47684635 0.4696756  0.46968985 0.46391509 0.46309379 0.4751861
#  0.47407983 0.47865107 0.24776215 0.5        0.52656434 0.56432749
#  0.61237785 0.68891688 0.66091523 0.72864322 0.6927593  0.68691358
#  0.68571429 0.69643683 0.68963984 0.69974446 0.68550666 0.68062397
#  0.68290598 0.70901423 0.73386667 0.69922054 0.71465428 0.68715596
#  0.68079226 0.7127716  0.67846608 0.68517265 0.65       0.65648855
#  0.50925926 0.64285714 0.64130435 0.68382353 0.58045977 0.62318841
#  0.60636183 0.57681941 0.60727969 0.58397366 0.5906527  0.59193438
#  0.58385093 0.58533724 0.59025788 0.59335624 0.58981861 0.58660657
#  0.58370183 0.58156912 0.59093851 0.58622951 0.59323116 0.59449071
#  0.58361544 0.58953168 0.60111188 0.60233918 0.60693215 0.61728395
#  0.61843169 0.62639246 0.62321429 0.62667946 0.63309353 0.64130435
#  0.63774912 0.63877266 0.63500931 0.66931217 0.6954023  0.54929577
#  0.40909091 0.6625     0.71084337 0.65988372 0.58898305 0.61577608
#  0.61849711 0.57777778 0.57063712 0.58589512 0.56513761 0.56737589
#  0.56115108 0.5492126  0.56340289 0.55538462 0.55098935 0.53680982
#  0.53424658 0.53620955 0.5371248  0.53488372 0.53109244 0.54545455
#  0.52753108 0.52205882 0.53759398 0.51978417 0.52355072 0.53757225
#  0.52859961 0.53862661 0.55337691 0.55324074 0.54566745 0.55361596
#  0.54219949 0.57368421 0.59654179 0.53501401 0.62126246 0.58450704
#  0.58450704 0.58119658 0.61792453 0.60888889 0.62559242 0.65088757
#  0.65644172 0.62430939 0.68243243 0.66956522 0.6884058  0.63636364
#  0.77419355 0.69387755]
# 200

# %% [markdown]
# The dataset is succesfully normalized

# %%
plot_spectral_signatures("indian_pines")
plot_spectral_signatures("salinas_valley")
plot_spectral_signatures("pavia_center")
plot_spectral_signatures("pavia_university")

# %%
print(plot_color_composites("indian_pines", composites=["RGB", "NIR-G-B"]))
print(plot_color_composites("salinas_valley", composites=["RGB", "NIR-G-B"]))
print(plot_color_composites("pavia_center", composites=["RGB", "NIR-G-B"]))
print(plot_color_composites("pavia_university", composites=["RGB", "NIR-G-B"]))
# Out:
# None
# None
# None
# None
